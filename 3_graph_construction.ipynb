# %% [markdown]
# # Construct Knowledge Graph

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
entities_df = pd.read_csv("data/entities_extracted.csv")
relations_df = pd.read_csv("data/relations.csv")

# %% [markdown]
# ### Initialize directed graph

# %%
G = nx.DiGraph()

# %% [markdown]
# ### Add nodes

# %%
for _, row in entities_df.iterrows():
    G.add_node(row['entity'], type=row['entity_type'], doi=row['id'])

# %% [markdown]
# ### Add edges

# %%
for _, row in relations_df.iterrows():
    if not G.has_node(row['source']):
        G.add_node(row['source'], type='UNKNOWN')

    if not G.has_node(row['target']):
        G.add_node(row['target'], type='UNKNOWN')

    G.add_edge(
        row['source'],
        row['target'],
        relation=row['relation'],
        sentence=row['sentence'],
        doi=row['doi']
    )

# %%
print("Nodes with attributes:")
print(G.nodes(data=True))
print("Edges with attributes:")
print(G.edges(data=True))
# Out:
# Nodes with attributes:
# [('dibasic', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.16.682669'}), ('OC43', {'type': 'DISEASE', 'doi': '10.1101/2025.09.28.25336743'}), ('infection', {'type': 'DISEASE', 'doi': '10.1101/2025.09.30.679491'}), ('viral infections', {'type': 'DISEASE', 'doi': '10.1101/2025.10.16.682991'}), ('trametinib', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.15.682635'}), ('sorafenib', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.15.682635'}), ('coronavirus infections', {'type': 'DISEASE', 'doi': '10.1101/2025.10.15.682635'}), ('SARS-CoV-2 infection', {'type': 'DISEASE', 'doi': '10.1101/2025.09.30.679491'}), ('Tyrosine', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683077'}), ('pan-coronaviruses infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683077'}), ('HGS deficiency', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683077'}), ('riboflavin tetrabutyrate', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683077'}), ('RTB', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683077'}), ('nucleic acid', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.15.682549'}), ('weight loss', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682000'}), ('nilotinib', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.12.681938'}), ('tecovirimat', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.12.681938'}), ('ST-246', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.12.681938'}), ('urea', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.11.681833'}), ('hydrogen bond donor', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.11.681833'}), ('once-daily', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.11.681833'}), ('uridine', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.682008'}), ('ARCA', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682008'}), ('PASC', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.682101'}), ('infected with SARS-CoV-2 and viral', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('neurocognitive and behavioral impairments', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('neuroinflammation', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('inflammation', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('chronic disease', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('respiratory disease', {'type': 'DISEASE', 'doi': '10.1101/2025.10.09.681417'}), ('COVID-19 disease', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682000'}), ('anti-CD44', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.682000'}), ('pulmonary infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682000'}), ('mucormycosis', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('diabetes', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('zinc', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('Rhizopus arrhizus', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('hydrogen peroxide', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('sodium chloride', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('amphotericin B', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('posaconazole', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('ergosterol', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('chitosan', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('iron', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('Candida albicans', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('fungal infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('coronavirus infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.09.680815'}), ('ATAC', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.09.681330'}), ('Respiratory infectious diseases', {'type': 'DISEASE', 'doi': '10.1101/2025.10.09.681417'}), ('upper respiratory tract', {'type': 'DISEASE', 'doi': '10.1101/2025.10.09.681417'}), ('Ankara-(MVA)-SARS-2-ST', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.07.25337492'}), ('140', {'type': 'CHEMICAL', 'doi': '10.1101/2025. ...
# Edges with attributes:
# [('OC43', 'OC43', {'relation': 'conclude', 'sentence': 'We conclude that the establishment of SARS-CoV-2-specific immune responses altered responses to sHCoVs in our cohort, particularly for OC43 and NL63.', 'doi': '10.1101/2025.09.28.25336743'}), ('OC43', 'NL63', {'relation': 'conclude', 'sentence': 'We conclude that the establishment of SARS-CoV-2-specific immune responses altered responses to sHCoVs in our cohort, particularly for OC43 and NL63.', 'doi': '10.1101/2025.09.28.25336743'}), ('infection', 'infection', {'relation': 'vary', 'sentence': 'Our study demonstrates that oral microbiota composition in adults varies according to COVID-19 severity, whereas such microbial shifts are not observed in asymptomatic pediatric populations, regardless of infection status.', 'doi': '10.1101/2025.09.30.679491'}), ('infection', 'neurocognitive and behavioral impairments', {'relation': 'exhibit', 'sentence': 'Following recovery from infection, female mice exhibited persistent neurocognitive and behavioral impairments, along with greater frequencies of inflammatory myeloid subsets, neuroinflammation, and dysregulated T cell subsets, including Tregs.', 'doi': '10.1101/2025.10.13.682101'}), ('infection', 'neuroinflammation', {'relation': 'exhibit', 'sentence': 'Following recovery from infection, female mice exhibited persistent neurocognitive and behavioral impairments, along with greater frequencies of inflammatory myeloid subsets, neuroinflammation, and dysregulated T cell subsets, including Tregs.', 'doi': '10.1101/2025.10.13.682101'}), ('trametinib', 'sorafenib', {'relation': 'identify', 'sentence': 'We identified four host-directed drugs, donepezil, dH-ergocristine, trametinib and sorafenib, that could potentially be repurposed to treat coronavirus infections.', 'doi': '10.1101/2025.10.15.682635'}), ('trametinib', 'coronavirus infections', {'relation': 'identify', 'sentence': 'We identified four host-directed drugs, donepezil, dH-ergocristine, trametinib and sorafenib, that could potentially be repurposed to treat coronavirus infections.', 'doi': '10.1101/2025.10.15.682635'}), ('sorafenib', 'coronavirus infections', {'relation': 'identify', 'sentence': 'We identified four host-directed drugs, donepezil, dH-ergocristine, trametinib and sorafenib, that could potentially be repurposed to treat coronavirus infections.', 'doi': '10.1101/2025.10.15.682635'}), ('SARS-CoV-2 infection', 'SARS-CoV-2 infection', {'relation': 'differ', 'sentence': 'Oral microbiota composition and diversity did not differ by SARS-CoV-2 infection status in children.', 'doi': '10.1101/2025.09.30.679491'}), ('SARS-CoV-2 infection', 'infection', {'relation': 'differ', 'sentence': 'Oral microbiota composition and diversity did not differ by SARS-CoV-2 infection status in children.', 'doi': '10.1101/2025.09.30.679491'}), ('Tyrosine', 'pan-coronaviruses infection', {'relation': 'perform', 'sentence': 'Here, we performed a genome-wide CRISPRi screening to identify the host protein, Hepatocyte Growth Factor-Regulated Tyrosine Kinase Substrate (HGS), as essential for the pan-coronaviruses infection both in vitro and in vivo.', 'doi': '10.1101/2025.10.17.683077'}), ('riboflavin tetrabutyrate', 'RTB', {'relation': 'identify', 'sentence': 'Leveraging this interaction, we designed M-derived peptides and screened over 5,000 FDA-approved drugs, identifying riboflavin tetrabutyrate (RTB).', 'doi': '10.1101/2025.10.17.683077'}), ('RTB', 'RTB', {'relation': 'identify', 'sentence': 'Collectively, our findings establish HGS as a druggable host target and identify RTB as a promising broad-spectrum antiviral candidate.', 'doi': '10.1101/2025.10.17.683077'}), ('weight loss', 'infection', {'relation': 'reduce', 'sentence': 'Here, we report that in mice infected with a mouse-adapted strain of SARS-CoV-2, treatment with a combination of two anti-CD44 monoclonal antibodies confers a significant survival benefit and reduces weight loss and clinical score of the mice on Day 4 post infection. ...

# %% [markdown]
# ## Visualization

# %%
from pyvis.network import Network
import matplotlib.pyplot as plt

# Get unique node types
node_types = list(set(data['type'] for _, data in G.nodes(data=True)))

# Generate a color map using matplotlib's tab20
colors = plt.cm.tab20.colors  # RGB tuples
type_to_color = {t: f"#{int(r*255):02x}{int(g*255):02x}{int(b*255):02x}" 
                 for t, (r, g, b) in zip(node_types, colors)}

net = Network(height="750px", width="100%", notebook=True, directed=True)

# Add nodes with colors based on type
for node, data in G.nodes(data=True):
    net.add_node(
        node,
        label=node,
        title=f"Type: {data.get('type')}\nDOI: {data.get('doi')}",
        color=type_to_color[data.get('type')]
    )

# Add edges
for source, target, data in G.edges(data=True):
    net.add_edge(
        source,
        target,
        label=data.get('relation'),
        title=f"Sentence: {data.get('sentence')}\nDOI: {data.get('doi')}",
        color="gray",
        width=2
    )

net.force_atlas_2based()
net.show_buttons(filter_=['physics'])
net.write_html("knowledge_graph.html", open_browser=True)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
