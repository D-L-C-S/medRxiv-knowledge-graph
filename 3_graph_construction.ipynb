# %% [markdown]
# # Construct Knowledge Graph

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
entities_df = pd.read_csv("data/entities_extracted.csv")
relations_df = pd.read_csv("data/relations.csv")

# %% [markdown]
# ### Initialize directed graph

# %%
G = nx.DiGraph()

# %% [markdown]
# ### Add nodes

# %%
for _, row in entities_df.iterrows():
    G.add_node(row['entity'], type=row['entity_type'], doi=row['id'])

# %% [markdown]
# ### Add edges

# %%
for _, row in relations_df.iterrows():
    if not G.has_node(row['source']):
        G.add_node(row['source'], type='UNKNOWN')

    if not G.has_node(row['target']):
        G.add_node(row['target'], type='UNKNOWN')

    G.add_edge(
        row['source'],
        row['target'],
        relation=row['relation'],
        sentence=row['sentence'],
        doi=row['doi']
    )

# %%
print("Nodes with attributes:")
print(G.nodes(data=True))
print("Edges with attributes:")
print(G.edges(data=True))
# Out:
# Nodes with attributes:
# [('infection', {'type': 'DISEASE', 'doi': '10.1101/2025.09.27.25336412'}), ('JN.1/KP.2', {'type': 'DISEASE', 'doi': '10.1101/2025.10.16.682893'}), ('S-induced', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.16.682893'}), ('acute respiratory syndrome coronavirus 2', {'type': 'DISEASE', 'doi': '10.1101/2025.10.16.682699'}), ('RBD', {'type': 'DISEASE', 'doi': '10.1101/2025.10.16.682699'}), ('{Delta}3a7b-Nluc', {'type': 'CHEMICAL', 'doi': '10.1101/2025.09.30.679586'}), ('ARM', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.16.682699'}), ('SARS-CoV-2 infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.11.681833'}), ('inflammation', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('viral infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683096'}), ('AXiAEC', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683096'}), ('ALI', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683096'}), ('SARS-CoV-2 infected', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683096'}), ('LOC SARS-CoV-2 infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683096'}), ('dibasic', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.16.682669'}), ('OC43', {'type': 'DISEASE', 'doi': '10.1101/2025.10.16.682669'}), ('viral infections', {'type': 'DISEASE', 'doi': '10.1101/2025.10.16.682991'}), ('trametinib', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.15.682635'}), ('sorafenib', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.15.682635'}), ('coronavirus infections', {'type': 'DISEASE', 'doi': '10.1101/2025.10.15.682635'}), ('Tyrosine', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683077'}), ('pan-coronaviruses infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683077'}), ('HGS deficiency', {'type': 'DISEASE', 'doi': '10.1101/2025.10.17.683077'}), ('riboflavin tetrabutyrate', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683077'}), ('RTB', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.17.683077'}), ('nucleic acid', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.15.682549'}), ('weight loss', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682000'}), ('nilotinib', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.12.681938'}), ('tecovirimat', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.12.681938'}), ('ST-246', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.12.681938'}), ('urea', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.11.681833'}), ('hydrogen bond donor', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.11.681833'}), ('once-daily', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.11.681833'}), ('uridine', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.682008'}), ('ARCA', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682008'}), ('PASC', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.682101'}), ('infected with SARS-CoV-2 and viral', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('neurocognitive and behavioral impairments', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('neuroinflammation', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('chronic disease', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682101'}), ('respiratory disease', {'type': 'DISEASE', 'doi': '10.1101/2025.10.09.681417'}), ('COVID-19 disease', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682000'}), ('anti-CD44', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.682000'}), ('pulmonary infection', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.682000'}), ('mucormycosis', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('diabetes', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('zinc', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('Rhizopus arrhizus', {'type': 'DISEASE', 'doi': '10.1101/2025.10.13.681985'}), ('hydrogen peroxide', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('sodium chloride', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('amphotericin B', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}), ('posaconazole', {'type': 'CHEMICAL', 'doi': '10.1101/2025.10.13.681985'}) ...
# Edges with attributes:
# [('infection', 'inflammation', {'relation': 'LABEL_1', 'sentence': 'The most severe manifestation of COVID-19 is observed in the distal lung, where SARS-CoV-2 infection can result in massive inflammation and barrier breakdown.', 'doi': '10.1101/2025.10.17.683096'}), ('infection', 'neurocognitive and behavioral impairments', {'relation': 'LABEL_1', 'sentence': 'Following recovery from infection, female mice exhibited persistent neurocognitive and behavioral impairments, along with greater frequencies of inflammatory myeloid subsets, neuroinflammation, and dysregulated T cell subsets, including Tregs.', 'doi': '10.1101/2025.10.13.682101'}), ('infection', 'neuroinflammation', {'relation': 'LABEL_1', 'sentence': 'Following recovery from infection, female mice exhibited persistent neurocognitive and behavioral impairments, along with greater frequencies of inflammatory myeloid subsets, neuroinflammation, and dysregulated T cell subsets, including Tregs.', 'doi': '10.1101/2025.10.13.682101'}), ('JN.1/KP.2', 'S-induced', {'relation': 'LABEL_1', 'sentence': 'We found that administration of the JN.1/KP.2 booster elicited broadly neutralizing antibody responses against recently circulating SARS-CoV-2 variants that were accounted for by recall of Wu S-induced immunity.', 'doi': '10.1101/2025.10.16.682893'}), ('{Delta}3a7b-Nluc', 'RBD', {'relation': 'LABEL_1', 'sentence': 'Using a nanoluciferase (Nluc)-expressing attenuated recombinant SARS-CoV-2 lacking the open reading frames (ORF) 3a and 7b ({Delta}3a7b-Nluc), we characterized resistance profiles of two broadly protective NAbs targeting the S receptor binding domain (RBD) in S1 (1301B7) and the stem helix domain (SH) in S2 (1249A8).', 'doi': '10.1101/2025.10.16.682699'}), ('ARM', 'RBD', {'relation': 'LABEL_1', 'sentence': 'In contrast, no ARM emerged under treatment with 1249A8, or an antibody cocktail of 1301B7 (RBD) + 1249A8 (SH).', 'doi': '10.1101/2025.10.16.682699'}), ('SARS-CoV-2 infection', 'inflammation', {'relation': 'LABEL_1', 'sentence': 'The most severe manifestation of COVID-19 is observed in the distal lung, where SARS-CoV-2 infection can result in massive inflammation and barrier breakdown.', 'doi': '10.1101/2025.10.17.683096'}), ('SARS-CoV-2 infection', 'infection', {'relation': 'LABEL_1', 'sentence': 'The most severe manifestation of COVID-19 is observed in the distal lung, where SARS-CoV-2 infection can result in massive inflammation and barrier breakdown.', 'doi': '10.1101/2025.10.17.683096'}), ('inflammation', 'PASC', {'relation': 'LABEL_1', 'sentence': 'Sex differences in inflammation and cognitive phenotypes during PASC were mediated by the presence of two X chromosomes.', 'doi': '10.1101/2025.10.13.682101'}), ('inflammation', 'chronic disease', {'relation': 'LABEL_1', 'sentence': 'XX animals independent of chromosome Y presented with neuroinflammation and PASC along with infection-induced upregulation of the X-linked genes Xist and Tlr7 that regulate inflammation and chronic disease outcomes.', 'doi': '10.1101/2025.10.13.682101'}), ('viral infection', 'infection', {'relation': 'LABEL_1', 'sentence': 'Human-derived microphysiological systems pose a promising new class of in vitro models to study viral infection in a relevant context.', 'doi': '10.1101/2025.10.17.683096'}), ('AXiAEC', 'SARS-CoV-2 infection', {'relation': 'LABEL_1', 'sentence': 'Using an immortalized alveolar epithelial cell line, AXiAEC, and human lung microvascular endothelial cells (hLMVEC) we established a SARS-CoV-2 infection model on a LOC system.', 'doi': '10.1101/2025.10.17.683096'}), ('AXiAEC', 'infection', {'relation': 'LABEL_1', 'sentence': 'Using an immortalized alveolar epithelial cell line, AXiAEC, and human lung microvascular endothelial cells (hLMVEC) we established a SARS-CoV-2 infection model on a LOC system.', 'doi': '10.1101/2025.10.17.683096'}), ('AXiAEC', 'ALI', {'relation': 'LABEL_1', 'sentence': 'Our results demonstrated that AXiAEC maturation at the air-liquid interface (ALI) ...

# %% [markdown]
# ## Visualization

# %%
from pyvis.network import Network
import matplotlib.pyplot as plt

# Get unique node types
node_types = list(set(data['type'] for _, data in G.nodes(data=True)))

# Generate a color map using matplotlib's tab20
colors = plt.cm.tab20.colors  # RGB tuples
type_to_color = {t: f"#{int(r*255):02x}{int(g*255):02x}{int(b*255):02x}" 
                 for t, (r, g, b) in zip(node_types, colors)}

net = Network(height="750px", width="100%", notebook=True, directed=True)

# Add nodes with colors based on type
for node, data in G.nodes(data=True):
    net.add_node(
        node,
        label=node,
        title=f"Type: {data.get('type')}\nDOI: {data.get('doi')}",
        color=type_to_color[data.get('type')]
    )

# Add edges
for source, target, data in G.edges(data=True):
    net.add_edge(
        source,
        target,
        label=data.get('relation'),
        title=f"Sentence: {data.get('sentence')}\nDOI: {data.get('doi')}",
        color="gray",
        width=2
    )

net.force_atlas_2based()
net.show_buttons(filter_=['physics'])
net.write_html("knowledge_graph.html", open_browser=True)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
