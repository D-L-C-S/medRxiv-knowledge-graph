# %% [markdown]
# # Structuring and Cleaning data

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import re
from datetime import datetime
import string
import json
import nltk

# %%
try:
    from nltk.corpus import stopwords
    stop_words = set(stopwords.words('english'))
except:
    nltk.download('stopwords')
    from nltk.corpus import stopwords
    stop_words = set(stopwords.words('english'))

# %% [markdown]
# ### Load data

# %%
with open('data/abstracts_raw.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

df = pd.DataFrame(data)
print(df.shape)
df.head
# Out:
# (30, 12)
# <bound method NDFrame.head of                         rel_doi  \
# 0     10.1101/2025.10.16.682669
# 1     10.1101/2025.10.16.682991
# 2     10.1101/2025.10.15.682635
# 3     10.1101/2025.10.17.682775
# 4     10.1101/2025.10.17.683077
# 5     10.1101/2025.10.15.682549
# 6     10.1101/2025.10.12.681938
# 7     10.1101/2025.10.11.681833
# 8     10.1101/2025.10.13.682008
# 9     10.1101/2025.10.13.682101
# 10    10.1101/2025.10.13.682000
# 11    10.1101/2025.10.13.681985
# 12    10.1101/2025.10.09.681538
# 13    10.1101/2025.10.09.680815
# 14    10.1101/2025.10.09.681330
# 15    10.1101/2025.10.09.681417
# 16  10.1101/2025.10.07.25337492
# 17  10.1101/2025.10.07.25337497
# 18  10.1101/2025.10.07.25337449
# 19    10.1101/2025.09.30.679586
# 20  10.1101/2025.10.05.25337392
# 21  10.1101/2025.10.02.25337223
# 22    10.1101/2025.10.03.679858
# 23    10.1101/2025.10.03.680419
# 24    10.1101/2025.10.03.680220
# 25  10.1101/2025.09.27.25336412
# 26  10.1101/2025.10.02.25337138
# 27  10.1101/2025.09.28.25336743
# 28    10.1101/2025.09.30.679491
# 29    10.1101/2025.09.22.677528
#
#                                             rel_title    rel_date rel_site  \
# 0   An unconventional HxD motif orchestrates coato...  2025-10-17  bioRxiv
# 1   A funnel approach to enable analyses of epitop...  2025-10-17  bioRxiv
# 2   Genome-wide Screening Identifies Unique Host-D...  2025-10-17  bioRxiv
# 3   Serological evidence of SARS-CoV-2 infection i...  2025-10-17  bioRxiv
# 4   Targeting the host factor HGS-viral membrane p...  2025-10-17  bioRxiv
# 5   Durability of DNA-LNP and mRNA-LNP Vaccine-Ind...  2025-10-15  bioRxiv
# 6   Effective repurposed antivirals against an eme...  2025-10-14  bioRxiv
# 7   Discovery of AVI-6451, a Potent and Selective ...  2025-10-14  bioRxiv
# 8   Circular mRNA against Clean Cap linear mRNA ve...  2025-10-14  bioRxiv
# 9   Mechanisms of sex differences in acute and lon...  2025-10-14  bioRxiv
# 10  The hyaluronan receptor CD44 drives COVID-19 s...  2025-10-14  bioRxiv
# 11  Role of zinc in growth, stress response and vi...  2025-10-14  bioRxiv
# 12  Clustering of SARS-CoV-2 membrane proteins in ...  2025-10-10  bioRxiv
# 13  mRNA poly(A)-tail length is a battleground for...  2025-10-10  bioRxiv
# 14  Predicting enhancer-gene links from single-cel...  2025-10-09  bioRxiv
# 15  A novel vaccination strategy induces vaccine-s...  2025-10-09  bioRxiv
# 16  Phase 1 Study of Safety, Reactogenicity, and I...  2025-10-08  medRxiv
# 17  Evaluating Rural/Urban HPV Vaccine Completion ...  2025-10-08  medRxiv
# 18  First-in-Human Study of a First-in-Class AI-De...  2025-10-08  medRxiv
# 19  Identification and characterization of a SARS-...  2025-10-07  bioRxiv
# 20  Spatiotemporal variation of COVID-19 case time...  2025-10-07  medRxiv
# 21  Nontuberculous Mycobacteria Species in Patient...  2025-10-07  medRxiv
# 22  Re-infection with SARS-CoV-2 is associated wit...  2025-10-06  bioRxiv
# 23  Template switching by coronavirus polymerase r...  2025-10-06  bioRxiv
# 24  Investigation of anti-SARS CoV-2 multimeric bi...  2025-10-05  bioRxiv
# 25  Epidemiology and Cluster Predictions on Preven...  2025-10-05  medRxiv
# 26  TACO: TabPFN Augmented Causal Outcomes for Ear...  2025-10-05  medRxiv
# 27  SARS-CoV-2 cross-reactive B-cells outnumber se...  2025-10-05  medRxiv
# 28  Oral Microbiota Composition in Children and Ad...  2025-10-04  bioRxiv
# 29  Computational Analysis of Silent Mutation Effe...  2025-10-03  bioRxiv
#
#                                              rel_link  \
# 0   https://biorxiv.org/cgi/content/short/2025.10....
# 1   https://biorxiv.org/cgi/content/short/2025.10....
# 2   https://biorxiv.org/cgi/content/short/2025.10....
# 3   https://biorxiv.org/cgi/content/short/2025.10....
# 4   https://biorxiv.org/cgi/content/short/2025.10....
# 5   https://biorxiv.org/cgi/content/short/2025.10....
# 6   https://biorxiv.org/cgi/content/short/2025.10....
# 7   https://biorxiv.org/cgi/content/short/2025.10....
# 8   https://biorxiv.org/cgi/content/short/2025.10....
# 9   https://biorxiv.org/cgi/content/short/2025.10....
# 10  https://biorxiv.org/cgi/content/short/2025.10....
# 11  https://biorxiv.org/cgi/content/short/2025.10....
# 12  https://biorxiv.org/cgi/content/short/2025.10....
# 13  https://biorxiv.org/cgi/content/short/2025.10....
# 14  https://biorxiv.org/cgi/content/short/2025.10....
# 15  https://biorxiv.org/cgi/content/short/2025.10....
# 16  https://medrxiv.org/cgi/content/short/2025.10....
# 17  https://medrxiv.org/cgi/content/short/2025.10....
# 18  https://medrxiv.org/cgi/content/short/2025.10....
# 19  https://biorxiv.org/cgi/content/short/2025.09....
# 20  https://medrxiv.org/cgi/content/short/2025.10....
# 21  https://medrxiv.org/cgi/content/short/2025.10....
# 22  https://biorxiv.org/cgi/content/short/2025.10....
# 23  https://biorxiv.org/cgi/content/short/2025.10....
# 24  https://biorxiv.org/cgi/content/short/2025.10....
# 25  https://medrxiv.org/cgi/content/short/2025.09....
# 26  https://medrxiv.org/cgi/content/short/2025.10....
# 27  https://medrxiv.org/cgi/content/short/2025.09....
# 28  https://biorxiv.org/cgi/content/short/2025.09....
# 29  https://biorxiv.org/cgi/content/short/2025.09....
#
#                                               rel_abs  rel_num_authors  \
# 0   Assembly of infectious coronaviruses requires ...               15
# 1   Protection from pathogenic organisms relies he...               10
# 2   SARS-CoV-2 is a positive-sense RNA virus and w...               16
# 3   SARS-CoV-2 is the viral agent of COVID-19 and ...               15
# 4   While current antivirals primarily target vira...               28
# 5   mRNA-lipid nanoparticle (LNP) vaccines induce ...               19
# 6   The ongoing global monkeypox virus (MPXV) outb...                8
# 7   The COVID-19 pandemic made plain the need for ...               19
# 8   The mRNA platform has revolutionised vaccine t...               18
# 9   While males are more likely to suffer severe o...               21
# 10  The novel respiratory disease COVID-19 caused ...               12
# 11  During COVID-19 pandemic, the cases of mucormy...                4
# 12  The accumulation of viral structural proteins ...                8
# 13  Most eukaryotic mRNAs contain a poly(A) tail, ...                6
# 14  Enhancers play an important role in transcript...                6
# 15  Respiratory infectious diseases are associated...                3
# 16  BackgroundExisting parenteral SARS-CoV-2 vacci...               17
# 17  BackgroundThe HPV vaccine provides parents wit...                2
# 18  BackgroundAntibodies against the SARS-CoV-2 sp...               19
# 19  Ensitrelvir is an antiviral drug that specific...               12
# 20  BackgroundAnalysing the spatiotemporal variati...                3
# 21  BackgroundThe incidence of nontuberculous myco...                6
# 22  The ease with which emerging SARS-CoV-2 varian...               13
# 23  Polymerase template switching is an essential ...               19
# 24  The spread of respiratory viruses, such as Inf...               23
# 25  BackgroundThe Severe Acute Respiratory Syndrom...                3
# 26  Long COVID affects 10-40% of COVID-19 survivor...                9
# 27  B-cell responses towards seasonal human corona...               13
# 28  BackgroundThe COVID-19 pandemic changed societ...               13
# 29  Graphical Abstract\n\nO_FIG O_LINKSMALLFIG WID...               15
#
#                                           rel_authors version      license  \
# 0   [{'author_name': 'Surovi Mohona', 'author_inst...       1     cc_by_nc
# 1   [{'author_name': 'Katherine A Richards', 'auth...       1        cc_no
# 2   [{'author_name': 'juveriya Qamar Khan', 'autho...       1        cc_no
# 3   [{'author_name': 'Joanna Vieira O'Neill', 'aut...       1        cc_by
# 4   [{'author_name': 'Xubing Long', 'author_inst':...       1     cc_by_nc
# 5   [{'author_name': 'Levi Tamming', 'author_inst'...       1  cc_by_nc_nd
# 6   [{'author_name': 'Huiyuan Zhou', 'author_inst'...       1        cc_no
# 7   [{'author_name': 'Priyadarshini Jaishankar', '...       1        cc_by
# 8   [{'author_name': 'Vladimir M. Vakhtinskii', 'a...       1  cc_by_nc_nd
# 9   [{'author_name': 'Jennifer A. Liu', 'author_in...       1  cc_by_nc_nd
# 10  [{'author_name': 'Duncan Hart', 'author_inst':...       1        cc_by
# 11  [{'author_name': 'RACHNA SINGH', 'author_inst'...       1        cc_no
# 12  [{'author_name': 'Joseph McTiernan', 'author_i...       1        cc_no
# 13  [{'author_name': 'Arash Latifkar', 'author_ins...       1        cc_by
# 14  [{'author_name': 'Xuan Liang', 'author_inst': ...       1        cc_no
# 15  [{'author_name': 'Rupsha Fraser', 'author_inst...       1        cc_no
# 16  [{'author_name': 'Jens M Hohlfeld', 'author_in...       1        cc_no
# 17  [{'author_name': 'Danya Schaefer', 'author_ins...       1        cc_by
# 18  [{'author_name': 'Francesco Borriello', 'autho...       1        cc_no
# 19  [{'author_name': 'Yao Ma', 'author_inst': 'Tex...       1        cc_no
# 20  [{'author_name': 'Khai Lin Kong', 'author_inst...       1        cc_no
# 21  [{'author_name': 'Platon Eliseev', 'author_ins...       1        cc_by
# 22  [{'author_name': 'Michelle Lilly', 'author_ins...       1  cc_by_nc_nd
# 23  [{'author_name': 'Asif Rakib', 'author_inst': ...       1     cc_by_nc
# 24  [{'author_name': 'Maximilian A. J. Harman', 'a...       1  cc_by_nc_nd
# 25  [{'author_name': 'Enock  Wabenga Robert Wantak...       1        cc_no
# 26  [{'author_name': 'Sindy Licette Pinero', 'auth...       1  cc_by_nc_nd
# 27  [{'author_name': 'Cristina Gonzalez Lopez', 'a...       1  cc_by_nc_nd
# 28  [{'author_name': 'Miguel Blanco-Fuertes', 'aut...       1  cc_by_nc_nd
# 29  [{'author_name': 'Adebayo Joseph Bello', 'auth...       1     cc_by_nc
#
#                    type                      category
# 0           new results                  biochemistry
# 1           new results                    immunology
# 2           new results                  microbiology
# 3           new results                  microbiology
# 4           new results                  microbiology
# 5           new results                    immunology
# 6           new results                     pathology
# 7           new results   pharmacology and toxicology
# 8           new results                    immunology
# 9           new results                    immunology
# 10          new results                    immunology
# 11          new results                  microbiology
# 12          new results                    biophysics
# 13          new results             molecular biology
# 14          new results                bioinformatics
# 15          new results                    immunology
# 16  PUBLISHAHEADOFPRINT          respiratory medicine
# 17  PUBLISHAHEADOFPRINT      public and global health
# 18  PUBLISHAHEADOFPRINT           infectious diseases
# 19          new results                  microbiology
# 20  PUBLISHAHEADOFPRINT           infectious diseases
# 21  PUBLISHAHEADOFPRINT           infectious diseases
# 22          new results                    immunology
# 23          new results                  microbiology
# 24          new results   pharmacology and toxicology
# 25  PUBLISHAHEADOFPRINT                  epidemiology
# 26  PUBLISHAHEADOFPRINT  genetic and genomic medicine
# 27  PUBLISHAHEADOFPRINT           infectious diseases
# 28          new results                  microbiology
# 29          new results                bioinformatics  >

# %% [markdown]
# ### Build nodes and edges for knowledge graph

# %%
nodes = []

for _, row in df.iterrows():
    doi = row['rel_doi']
    title = row['rel_title']
    site = row.get('rel_site', '')
    date = row.get('rel_date', '')

    nodes.append({
        'id': doi,
        'label': 'Article',
        'title': title,
        'site': site,
        'date': date
    })

# %% [markdown]
# #### Dropping duplicates(if any)

# %%
nodes_df = pd.DataFrame(nodes).drop_duplicates(subset=['id'])

print(f"Nodes: {len(nodes_df)}")
# Out:
# Nodes: 30

# %% [markdown]
# ### Export to csv

# %%
nodes_df.to_csv('data/entities_extracted.csv', index=False)
