# %% [markdown]
# # Identify relations between entities extracted from step 2

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
import json
import re
from nltk.tokenize import sent_tokenize
import spacy

# %% [markdown]
# ### Load data

# %%
with open('../data/abstracts_raw.json', 'r', encoding='utf-8') as f:
    abstracts = json.load(f)

# %% [markdown]
# ### Load model

# %%
# %pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz
nlp = spacy.load("en_ner_bc5cdr_md")
# Out:
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_ner_bc5cdr_md-0.5.4.tar.gz (119.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: spacy<3.8.0,>=3.7.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from en_ner_bc5cdr_md==0.5.4) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.12.3)
# Requirement already satisfied: jinja2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.1.6)
# Requirement already satisfied: setuptools in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2025.10.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.1.5)
# Requirement already satisfied: colorama in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (14.2.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (7.4.0)
# Requirement already satisfied: wrapt in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.0.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.4->en_ner_bc5cdr_md==0.5.4) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Clean text

# %%
def clean_text(text):
    text = re.sub(r'[\x00-\x1f\x7f-\x9f]', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %% [markdown]
# ### Extract entities

# %%
print("Extracting entities from abstracts...")
entity_rows = []

for abstract in abstracts:
    doi = abstract['rel_doi']
    text = clean_text(abstract.get('rel_abs', ''))
    
    if not text:
        continue
    
    doc = nlp(text)
    
    for ent in doc.ents:
        # BC5CDR labels: CHEMICAL (drugs), DISEASE (diseases/symptoms)
        entity_type = 'Drug' if ent.label_ == 'CHEMICAL' else 'Disease'
        
        entity_rows.append({
            'id': doi,
            'entity': ent.text,
            'entity_type': entity_type,
            'original_label': ent.label_
        })

entities_df = pd.DataFrame(entity_rows)
entities_df = entities_df.drop_duplicates(subset=['id', 'entity', 'entity_type'])
entities_df.to_csv('../data/entities_extracted.csv', index=False)
print(f"Extracted {len(entities_df)} unique entities")
print(f"  - Drugs: {len(entities_df[entities_df['entity_type'] == 'Drug'])}")
print(f"  - Diseases: {len(entities_df[entities_df['entity_type'] == 'Disease'])}")
# Out:
# Extracting entities from abstracts...
# Extracted 109 unique entities
#   - Drugs: 38
#   - Diseases: 71

# %% [markdown]
# ### Map entities to sentences and generate edges

# %%
RELATION_PATTERNS = {
    'treats': [
        r'\b(treat|treated|treating|treatment|therapy|therapeutic)\b',
        r'\b(effective|efficacy|administered|prescribed)\b',
        r'\b(cure|cures|curing|remedy)\b'
    ],
    'causes': [
        r'\b(cause|caused|causing|induce|induced|inducing)\b',
        r'\b(lead to|leads to|result in|results in)\b',
        r'\b(associated with|linked to|related to)\b'
    ],
    'associated_with': [
        r'\b(associated|correlation|correlated|relationship)\b',
        r'\b(found in|observed in|detected in)\b',
        r'\b(present in|prevalence)\b'
    ]
}

def infer_relation(sentence, source_type, target_type):
    sentence_lower = sentence.lower()
    
    # Drug -> Disease = treats
    if source_type == 'Drug' and target_type == 'Disease':
        for pattern in RELATION_PATTERNS['treats']:
            if re.search(pattern, sentence_lower):
                return 'treats'
        return 'associated_with'
    
    # Disease -> Drug = treated_by
    elif source_type == 'Disease' and target_type == 'Drug':
        for pattern in RELATION_PATTERNS['treats']:
            if re.search(pattern, sentence_lower):
                return 'treated_by'
        return 'associated_with'
    
    # Disease -> Disease = causes or associated_with
    elif source_type == 'Disease' and target_type == 'Disease':
        for pattern in RELATION_PATTERNS['causes']:
            if re.search(pattern, sentence_lower):
                return 'causes'
        return 'associated_with'
    
    # Default
    return 'associated_with'

# %%
print("\nExtracting relations between entities...")

edges = []

for abstract in abstracts:
    doi = abstract['rel_doi']
    text = clean_text(abstract.get('rel_abs', ''))
    
    if not text:
        continue
    
    sentences = sent_tokenize(text)
    abstract_entities = entities_df[entities_df['id'] == doi]
    
    for sent in sentences:
        entities_in_sentence = []
        for _, row in abstract_entities.iterrows():
            if row['entity'] in sent:
                entities_in_sentence.append(row)
        
        if len(entities_in_sentence) > 1:
            for i, e1 in enumerate(entities_in_sentence):
                for e2 in entities_in_sentence[i+1:]:
                    source = e1['entity']
                    target = e2['entity']
                    source_type = e1['entity_type']
                    target_type = e2['entity_type']
                    
                    # Infer relation
                    relation = infer_relation(sent, source_type, target_type)
                    
                    # Calculate confidence based on sentence proximity
                    source_pos = sent.find(source)
                    target_pos = sent.find(target)
                    distance = abs(source_pos - target_pos)
                    confidence = 1 / (1 + distance / 100)  # Normalized distance score
                    
                    edges.append({
                        'source': source,
                        'target': target,
                        'source_type': source_type,
                        'target_type': target_type,
                        'relation': relation,
                        'confidence': confidence,
                        'sentence': sent[:200],  # Truncate for readability
                        'doi': doi
                    })
# Out:
# Extracting relations between entities...

# %%
edges_df = pd.DataFrame(edges)
edges_df = edges_df.drop_duplicates(subset=['source', 'target', 'relation'])
edges_df.to_csv('../data/relations.csv', index=False)
print(f"Generated {len(edges_df)} relations")

# Print relation statistics
print("\nRelation types distribution:")
for rel, count in edges_df['relation'].value_counts().items():
    print(f"  - {rel}: {count}")
# Out:
# Generated 80 relations
#
# Relation types distribution:
#   - associated_with: 64
#   - causes: 10
#   - treated_by: 3
#   - treats: 3
