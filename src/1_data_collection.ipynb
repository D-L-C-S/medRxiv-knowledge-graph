# %% [markdown]
# # Collect and store ~20–30 medRxiv abstracts related to infectious diseases.

# %% [markdown]
# ### Import required libraries

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: annotated-types==0.7.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: asttokens==3.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: blis==0.7.11 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 3)) (0.7.11)
# Requirement already satisfied: catalogue==2.0.10 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 4)) (2.0.10)
# Requirement already satisfied: certifi==2025.10.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: charset-normalizer==3.4.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: click==8.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 7)) (8.3.0)
# Requirement already satisfied: cloudpathlib==0.23.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 8)) (0.23.0)
# Requirement already satisfied: colorama==0.4.6 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: comm==0.2.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: confection==0.1.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 11)) (0.1.5)
# Requirement already satisfied: contourpy==1.3.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 12)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: cymem==2.0.11 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 14)) (2.0.11)
# Requirement already satisfied: debugpy==1.8.17 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 15)) (1.8.17)
# Requirement already satisfied: decorator==5.2.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 16)) (5.2.1)
# Requirement already satisfied: executing==2.2.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 17)) (2.2.1)
# Requirement already satisfied: filelock==3.20.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 18)) (3.20.0)
# Requirement already satisfied: fonttools==4.60.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 19)) (4.60.1)
# Requirement already satisfied: fsspec==2025.9.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 20)) (2025.9.0)
# Requirement already satisfied: huggingface-hub==0.35.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 21)) (0.35.3)
# Requirement already satisfied: idna==3.11 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 22)) (3.11)
# Requirement already satisfied: ipykernel==7.0.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 23)) (7.0.1)
# Requirement already satisfied: ipython==9.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 24)) (9.6.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 26)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 27)) (3.1.6)
# Requirement already satisfied: joblib==1.5.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 28)) (1.5.2)
# Requirement already satisfied: jsonpickle==4.1.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 29)) (4.1.1)
# Requirement already satisfied: jupyter_client==8.6.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 30)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.9.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 31)) (5.9.1)
# Requirement already satisfied: kiwisolver==1.4.9 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 32)) (1.4.9)
# Requirement already satisfied: langcodes==3.5.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 33)) (3.5.0)
# Requirement already satisfied: language_data==1.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 34)) (1.3.0)
# Requirement already satisfied: marisa-trie==1.3.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 35)) (1.3.1)
# Requirement already satisfied: markdown-it-py==4.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 36)) (4.0.0)
# Requirement already satisfied: MarkupSafe==3.0.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 37)) (3.0.3)
# Requirement already satisfied: matplotlib==3.10.7 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 38)) (3.10.7)
# Requirement already satisfied: matplotlib-inline==0.1.7 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 39)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 40)) (0.1.2)
# Requirement already satisfied: mpmath==1.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 41)) (1.3.0)
# Requirement already satisfied: murmurhash==1.0.13 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 42)) (1.0.13)
# Requirement already satisfied: nest-asyncio==1.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 43)) (1.6.0)
# Requirement already satisfied: networkx==3.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 44)) (3.5)
# Requirement already satisfied: nltk==3.9.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 45)) (3.9.2)
# Requirement already satisfied: numpy==1.26.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 46)) (1.26.4)
# Requirement already satisfied: packaging==25.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 47)) (25.0)
# Requirement already satisfied: pandas==2.3.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 48)) (2.3.3)
# Requirement already satisfied: parso==0.8.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 49)) (0.8.5)
# Requirement already satisfied: pillow==12.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 50)) (12.0.0)
# Requirement already satisfied: platformdirs==4.5.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 51)) (4.5.0)
# Requirement already satisfied: preshed==3.0.10 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 52)) (3.0.10)
# Requirement already satisfied: prompt_toolkit==3.0.52 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 53)) (3.0.52)
# Requirement already satisfied: psutil==7.1.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 54)) (7.1.1)
# Requirement already satisfied: pure_eval==0.2.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 55)) (0.2.3)
# Requirement already satisfied: pydantic==2.12.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 56)) (2.12.3)
# Requirement already satisfied: pydantic_core==2.41.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 57)) (2.41.4)
# Requirement already satisfied: Pygments==2.19.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 58)) (2.19.2)
# Requirement already satisfied: pyparsing==3.2.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 59)) (3.2.5)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 60)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 61)) (2025.2)
# Requirement already satisfied: pyvis==0.3.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 62)) (0.3.2)
# Requirement already satisfied: PyYAML==6.0.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 63)) (6.0.3)
# Requirement already satisfied: pyzmq==27.1.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 64)) (27.1.0)
# Requirement already satisfied: regex==2025.10.22 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 65)) (2025.10.22)
# Requirement already satisfied: requests==2.32.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 66)) (2.32.5)
# Requirement already satisfied: rich==14.2.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 67)) (14.2.0)
# Requirement already satisfied: safetensors==0.6.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 68)) (0.6.2)
# Requirement already satisfied: scikit-learn==1.7.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 69)) (1.7.2)
# Requirement already satisfied: scipy==1.16.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 70)) (1.16.2)
# Requirement already satisfied: setuptools==80.9.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 71)) (80.9.0)
# Requirement already satisfied: shellingham==1.5.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 72)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 73)) (1.17.0)
# Requirement already satisfied: smart_open==7.4.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 74)) (7.4.0)
# Requirement already satisfied: spacy==3.7.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 75)) (3.7.5)
# Requirement already satisfied: spacy-legacy==3.0.12 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 76)) (3.0.12)
# Requirement already satisfied: spacy-loggers==1.0.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 77)) (1.0.5)
# Requirement already satisfied: srsly==2.5.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 78)) (2.5.1)
# Requirement already satisfied: stack-data==0.6.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 79)) (0.6.3)
# Requirement already satisfied: sympy==1.14.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 80)) (1.14.0)
# Requirement already satisfied: thinc==8.2.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 81)) (8.2.5)
# Requirement already satisfied: threadpoolctl==3.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 82)) (3.6.0)
# Requirement already satisfied: tokenizers==0.22.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 83)) (0.22.1)
# Requirement already satisfied: torch==2.9.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 84)) (2.9.0)
# Requirement already satisfied: tornado==6.5.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 85)) (6.5.2)
# Requirement already satisfied: tqdm==4.67.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 86)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 87)) (5.14.3)
# Requirement already satisfied: transformers==4.57.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 88)) (4.57.1)
# Requirement already satisfied: typer==0.20.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 89)) (0.20.0)
# Requirement already satisfied: typing-inspection==0.4.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 90)) (0.4.2)
# Requirement already satisfied: typing_extensions==4.15.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 91)) (4.15.0)
# Requirement already satisfied: tzdata==2025.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 92)) (2025.2)
# Requirement already satisfied: urllib3==2.5.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 93)) (2.5.0)
# Requirement already satisfied: wasabi==1.1.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 94)) (1.1.3)
# Requirement already satisfied: wcwidth==0.2.14 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 95)) (0.2.14)
# Requirement already satisfied: weasel==0.4.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 96)) (0.4.1)
# Requirement already satisfied: wrapt==2.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r ../requirements.txt (line 97)) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
from pathlib import Path

# %% [markdown]
# ### Setting up data folder

# %%
data_path = Path("../data")
data_path.mkdir(exist_ok=True)

# %% [markdown]
# ### Downloading medRxiv abstracts

# %%
url = "https://api.biorxiv.org/covid19/0/json"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    
    abstracts = data.get("collection", [])
    print(f"Fetched {len(abstracts)} abstracts")

else:
    print("Failed to retrieve data:", response.status_code)
    abstracts = []
# Out:
# Fetched 30 abstracts

# %% [markdown]
# ### Save abstracts

# %%
with open(data_path / "abstracts_raw.json", "w", encoding="utf-8") as f:
    json.dump(abstracts, f, ensure_ascii=False, indent=4)

print(f"Abstracts saved to {data_path / 'abstracts_raw.json'}")
# Out:
# Abstracts saved to ..\data\abstracts_raw.json

# %% [markdown]
# ### Verify data

# %%
if abstracts:
    sample = abstracts[0]
    print("Sample abstract:")
    print(f"Title: {sample.get('rel_title')}")
    print(f"DOI: {sample.get('rel_doi')}")
    print(f"Authors: {sample.get('rel_authors')}")
    print(f"Date: {sample.get('rel_date')}")
    
    abstract_text = sample.get('rel_abs') or ""
    print(f"Abstract: {abstract_text[:200]}...")
# Out:
# Sample abstract:
# Title: Repeated COVID-19 vaccine boosters elicit variant-specific memory B cells in humans
# DOI: 10.1101/2025.10.16.682893
# Authors: [{'author_name': 'M. Alejandra Tortorici', 'author_inst': 'University of Washington'}, {'author_name': 'Kaitlin R Sprouse', 'author_inst': 'University of Washington'}, {'author_name': 'Amin Addetia', 'author_inst': 'University of Washington'}, {'author_name': 'Jack T Brown', 'author_inst': 'University of Washington'}, {'author_name': 'Alex Harteloo', 'author_inst': 'University of Washington'}, {'author_name': 'Anna Elias-Warren', 'author_inst': 'University of Washington'}, {'author_name': 'Helen Y Chiu', 'author_inst': 'University of Washington'}, {'author_name': 'David Veesler', 'author_inst': 'University of Washington'}]
# Date: 2025-10-20
# Abstract: The first exposure to a pathogen or an antigen profoundly impacts immune responses upon subsequent encounter with related pathogens. This immune imprinting explains that infection or vaccination with ...
