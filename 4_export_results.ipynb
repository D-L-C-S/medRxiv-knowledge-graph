# %% [markdown]
# ## Exporting results as (entity1, relation, entity2, confidence)

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
from collections import Counter

# %% [markdown]
# ### Load csv

# %%
edges_df = pd.read_csv('data/relations.csv')

# %% [markdown]
# ### Compute confidence score

# %%
edges_df = edges_df.rename(columns={'source': 'entity_1', 'target': 'entity_2'})

edge_counter = Counter(
    [(row['entity_1'], row['relation'], row['entity_2']) for _, row in edges_df.iterrows()]
)
max_count = max(edge_counter.values())

edges_df['confidence'] = edges_df.apply(
    lambda row: 0.5*row['distance_score'] + 0.5*(edge_counter[(row['entity_1'], row['relation'], row['entity_2'])]/max_count),
    axis=1
)

# %%
triples_df = edges_df[['entity_1', 'relation', 'entity_2', 'confidence']]
triples_df.head
# Out:
# <bound method NDFrame.head of                       entity_1  relation  \
# 0                   trametinib  identify
# 1                   trametinib  identify
# 2                    sorafenib  identify
# 3                     Tyrosine   perform
# 4     riboflavin tetrabutyrate  identify
# ...                        ...       ...
# 1023                 infection    differ
# 1024      SARS-CoV-2 infection    differ
# 1025                 infection      vary
# 1026                         K      play
# 1027                       U/A    impact
#
#                                        entity_2  confidence
# 0                                     sorafenib    0.178571
# 1                        coronavirus infections    0.053571
# 2                        coronavirus infections    0.061905
# 3                   pan-coronaviruses infection    0.053571
# 4                                           RTB    0.160714
# ...                                         ...         ...
# 1023                                  infection    0.511905
# 1024                                  infection    0.297619
# 1025                                  infection    0.511905
# 1026  DTLVardef@1696837_HPS_FORMAT_FIGEXP M_FIG    0.057359
# 1027                                        G/C    0.178571
#
# [1028 rows x 4 columns]>

# %%
triples_df.to_csv('output/triples_output.csv', index=False)
