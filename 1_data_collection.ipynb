# %% [markdown]
# # Collect and store ~20–30 medRxiv abstracts related to infectious diseases.

# %% [markdown]
# ### Import required libraries

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: annotated-types==0.7.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: asttokens==3.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: blis==1.2.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: catalogue==2.0.10 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 4)) (2.0.10)
# Requirement already satisfied: certifi==2025.10.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 5)) (2025.10.5)
# Requirement already satisfied: charset-normalizer==3.4.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 6)) (3.4.4)
# Requirement already satisfied: click==8.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 7)) (8.3.0)
# Requirement already satisfied: cloudpathlib==0.23.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 8)) (0.23.0)
# Requirement already satisfied: colorama==0.4.6 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: comm==0.2.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 10)) (0.2.3)
# Requirement already satisfied: confection==0.1.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 11)) (0.1.5)
# Requirement already satisfied: conllu==6.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 12)) (6.0.0)
# Requirement already satisfied: contourpy==1.3.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 13)) (1.3.3)
# Requirement already satisfied: cycler==0.12.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: cymem==2.0.11 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 15)) (2.0.11)
# Requirement already satisfied: debugpy==1.8.17 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 16)) (1.8.17)
# Requirement already satisfied: decorator==5.2.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 17)) (5.2.1)
# Requirement already satisfied: executing==2.2.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 18)) (2.2.1)
# Requirement already satisfied: fonttools==4.60.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 19)) (4.60.1)
# Requirement already satisfied: idna==3.11 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 20)) (3.11)
# Requirement already satisfied: ipykernel==7.0.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 21)) (7.0.1)
# Requirement already satisfied: ipython==9.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 22)) (9.6.0)
# Requirement already satisfied: ipython_pygments_lexers==1.1.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 23)) (1.1.1)
# Requirement already satisfied: jedi==0.19.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 24)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 25)) (3.1.6)
# Requirement already satisfied: joblib==1.5.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 26)) (1.5.2)
# Requirement already satisfied: jupyter_client==8.6.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 27)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.9.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 28)) (5.9.1)
# Requirement already satisfied: kiwisolver==1.4.9 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 29)) (1.4.9)
# Requirement already satisfied: langcodes==3.5.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 30)) (3.5.0)
# Requirement already satisfied: language_data==1.3.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 31)) (1.3.0)
# Requirement already satisfied: marisa-trie==1.3.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 32)) (1.3.1)
# Requirement already satisfied: markdown-it-py==4.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 33)) (4.0.0)
# Requirement already satisfied: MarkupSafe==3.0.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 34)) (3.0.3)
# Requirement already satisfied: matplotlib==3.10.7 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 35)) (3.10.7)
# Requirement already satisfied: matplotlib-inline==0.1.7 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 36)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 37)) (0.1.2)
# Requirement already satisfied: murmurhash==1.0.13 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 38)) (1.0.13)
# Requirement already satisfied: nest-asyncio==1.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 39)) (1.6.0)
# Requirement already satisfied: networkx==3.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 40)) (3.5)
# Requirement already satisfied: nltk==3.9.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 41)) (3.9.2)
# Requirement already satisfied: nmslib-metabrainz==2.1.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 42)) (2.1.3)
# Requirement already satisfied: numpy==1.26.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 43)) (1.26.4)
# Requirement already satisfied: packaging==25.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 44)) (25.0)
# Requirement already satisfied: pandas==2.3.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 45)) (2.3.3)
# Requirement already satisfied: parso==0.8.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 46)) (0.8.5)
# Requirement already satisfied: pillow==12.0.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 47)) (12.0.0)
# Requirement already satisfied: platformdirs==4.5.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 48)) (4.5.0)
# Requirement already satisfied: preshed==3.0.10 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 49)) (3.0.10)
# Requirement already satisfied: prompt_toolkit==3.0.52 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 50)) (3.0.52)
# Requirement already satisfied: psutil==7.1.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 51)) (7.1.0)
# Requirement already satisfied: pure_eval==0.2.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 52)) (0.2.3)
# Requirement already satisfied: pybind11==3.0.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 53)) (3.0.1)
# Requirement already satisfied: pydantic==2.12.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 54)) (2.12.3)
# Requirement already satisfied: pydantic_core==2.41.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 55)) (2.41.4)
# Requirement already satisfied: Pygments==2.19.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 56)) (2.19.2)
# Requirement already satisfied: pyparsing==3.2.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 57)) (3.2.5)
# Requirement already satisfied: pysbd==0.3.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 58)) (0.3.4)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 59)) (2.9.0.post0)
# Requirement already satisfied: pytz==2025.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 60)) (2025.2)
# Requirement already satisfied: pyzmq==27.1.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 61)) (27.1.0)
# Requirement already satisfied: regex==2025.9.18 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 62)) (2025.9.18)
# Requirement already satisfied: requests==2.32.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 63)) (2.32.5)
# Requirement already satisfied: rich==14.2.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 64)) (14.2.0)
# Requirement already satisfied: scikit-learn==1.7.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 65)) (1.7.2)
# Requirement already satisfied: scipy==1.16.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 66)) (1.16.2)
# Requirement already satisfied: scispacy==0.6.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 67)) (0.6.2)
# Requirement already satisfied: setuptools==80.9.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 68)) (80.9.0)
# Requirement already satisfied: shellingham==1.5.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 69)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 70)) (1.17.0)
# Requirement already satisfied: smart_open==7.3.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 71)) (7.3.1)
# Requirement already satisfied: spacy==3.8.7 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 72)) (3.8.7)
# Requirement already satisfied: spacy-legacy==3.0.12 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 73)) (3.0.12)
# Requirement already satisfied: spacy-loggers==1.0.5 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 74)) (1.0.5)
# Requirement already satisfied: srsly==2.5.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 75)) (2.5.1)
# Requirement already satisfied: stack-data==0.6.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 76)) (0.6.3)
# Requirement already satisfied: thinc==8.3.4 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 77)) (8.3.4)
# Requirement already satisfied: threadpoolctl==3.6.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 78)) (3.6.0)
# Requirement already satisfied: tornado==6.5.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 79)) (6.5.2)
# Requirement already satisfied: tqdm==4.67.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 80)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 81)) (5.14.3)
# Requirement already satisfied: typer==0.19.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 82)) (0.19.2)
# Requirement already satisfied: typing-inspection==0.4.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 83)) (0.4.2)
# Requirement already satisfied: typing_extensions==4.15.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 84)) (4.15.0)
# Requirement already satisfied: tzdata==2025.2 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 85)) (2025.2)
# Requirement already satisfied: urllib3==2.5.0 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 86)) (2.5.0)
# Requirement already satisfied: wasabi==1.1.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 87)) (1.1.3)
# Requirement already satisfied: wcwidth==0.2.14 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 88)) (0.2.14)
# Requirement already satisfied: weasel==0.4.1 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 89)) (0.4.1)
# Requirement already satisfied: wrapt==1.17.3 in d:\medrxiv knowledge graph\medrxiv-knowledge-graph\venv\lib\site-packages (from -r requirements.txt (line 90)) (1.17.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
from pathlib import Path

# %% [markdown]
# ### Setting up data folder

# %%
data_path = Path("data")
data_path.mkdir(exist_ok=True)

# %% [markdown]
# ### Downloading medRxiv abstracts

# %%
url = "https://api.biorxiv.org/covid19/0/json"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    
    abstracts = data.get("collection", [])
    print(f"Fetched {len(abstracts)} abstracts")

else:
    print("Failed to retrieve data:", response.status_code)
    abstracts = []
# Out:
# Fetched 30 abstracts

# %% [markdown]
# ### Save abstracts

# %%
with open(data_path / "abstracts_raw.json", "w", encoding="utf-8") as f:
    json.dump(abstracts, f, ensure_ascii=False, indent=4)

print(f"Abstracts saved to {data_path / 'abstracts_raw.json'}")
# Out:
# Abstracts saved to data\abstracts_raw.json

# %% [markdown]
# ### Verify data

# %%
if abstracts:
    sample = abstracts[0]
    print("Sample abstract:")
    print(f"Title: {sample.get('rel_title')}")
    print(f"DOI: {sample.get('rel_doi')}")
    print(f"Authors: {sample.get('rel_authors')}")
    print(f"Date: {sample.get('rel_date')}")
    
    abstract_text = sample.get('rel_abs') or ""
    print(f"Abstract: {abstract_text[:200]}...")
# Out:
# Sample abstract:
# Title: An unconventional HxD motif orchestrates coatomer-dependent coronavirus morphogenesis
# DOI: 10.1101/2025.10.16.682669
# Authors: [{'author_name': 'Surovi Mohona', 'author_inst': 'Loyola University Chicago'}, {'author_name': 'Anil K Shakya', 'author_inst': 'University of Maryland Baltimore'}, {'author_name': 'Suruchi Singh', 'author_inst': 'University of Maryland Baltimore'}, {'author_name': 'Fiona L Kearns', 'author_inst': 'University of California, San Diego'}, {'author_name': 'Kezia Jemison', 'author_inst': 'University of California, San Diego'}, {'author_name': 'Satchal K Erramilli', 'author_inst': 'The University of Chicago'}, {'author_name': 'Debajit Dey', 'author_inst': 'University of Maryland Baltimore'}, {'author_name': 'Enya Qing', 'author_inst': 'Loyola University Chicago'}, {'author_name': 'Benjamin C Jennings', 'author_inst': 'Washington University School of Medicine'}, {'author_name': 'Balraj Doray', 'author_inst': 'Washington University School of Medicine'}, {'author_name': 'Anthony A Kossiakoff', 'author_inst': 'The University of Chicago'}, {'author_name': 'Rommie E Amaro', 'author_inst': 'University of California, San Diego'}, {'author_name': 'Thomas Klose', 'author_inst': 'Purdue University'}, {'author_name': 'Tom Gallagher', 'author_inst': 'Loyola University Chicago'}, {'author_name': 'S Saif Hasan', 'author_inst': 'University of Maryland Baltimore'}]
# Date: 2025-10-17
# Abstract: Assembly of infectious coronaviruses requires spike (S) protein trafficking by host coatomer, typically via a dibasic signal in the S cytoplasmic tail. However, the human embecoviruses HKU1 and OC43, ...
